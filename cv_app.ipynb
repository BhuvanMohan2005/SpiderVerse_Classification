# %%
from ultralytics import YOLO
import cv2

model = YOLO("best.pt")

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model.predict(frame)

    label = results[0].names[results[0].probs.top1]

    cv2.putText(frame, label, (20,40),
                cv2.FONT_HERSHEY_SIMPLEX,
                1, (0,255,0), 2)

    cv2.imshow("SpiderVerse Classifier", frame)

    key = cv2.waitKey(1) & 0xFF
    if key == 27 or key == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
#model.export(format="onnx")

# %%
model.export(format="tflite")
# Out:
# Ultralytics 8.4.21 🚀 Python-3.13.0 torch-2.10.0 CPU (Apple M1)
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 224, 224) BCHW and output shape(s) (1, 8) (2.8 MB)
